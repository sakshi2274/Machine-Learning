# %%
#Predicting if a person would buy life insurance based on his age using logistic regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker="*",color="Red")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train , y_test = train_test_split(df[['age']],df.bought_insurance, train_size=0.8)

# %%
X_train
# Out:
#     age
# 25   54
# 16   25
# 12   27
# 19   18
# 14   49
# 23   45
# 5    56
# 11   28
# 15   55
# 2    47
# 9    61
# 26   23
# 7    60
# 1    25
# 17   58
# 22   40
# 21   26
# 13   29
# 8    62
# 18   19
# 4    46

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 3    52
# 20   21
# 10   18
# 0    22
# 6    55
# 24   50

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[2.18085030e-03, 9.97819150e-01],
#        [9.66666016e-01, 3.33339835e-02],
#        [9.86426453e-01, 1.35735472e-02],
#        [9.55257007e-01, 4.47429934e-02],
#        [8.71391459e-04, 9.99128609e-01],
#        [4.01619118e-03, 9.95983809e-01]])

# %%
model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
y_test
# Out:
# 3     0
# 20    0
# 10    0
# 0     0
# 6     0
# 24    1
# Name: bought_insurance, dtype: int64

# %%
y_predicted
# Out:
# array([1, 0, 0, 0, 1, 1])

# %%
model.coef_
# Out:
# array([[0.30623009]])

# %%
model.intercept_
# Out:
# array([-9.79810758])

# %%
import math
def sigmoid(x):
    return 1 / (1+ math.exp(-x))

def prediction_function(age):
    z=0.12 * age - 4.91      #0.04150133 ~ 0.042 and -1.52726963
    y=sigmoid(z)
    return y

# %%
age = 43
prediction_function(age)
# Out:
# 0.5621765008857981

# %%
age = 35
prediction_function(age)
# Out:
# 0.3295988401911314
